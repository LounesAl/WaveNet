# %%
import librosa
import librosa.display
import IPython.display as ipd
import matplotlib.pyplot as plt 
import numpy as np

# %% [markdown]
# # Mfcc

# %%
audio_file='p225_001_mic1.flac'
#please call stella
audio_file='demo.wav'
audio_file
# Out:
# 'demo.wav'

# %%
ipd.Audio(audio_file)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
signal,sr=librosa.load(audio_file)

# %%
signal.shape
sr
# Out:
# 16000

# %%
#number of channel is 20
# sample rate is 16000
sr=16000

mfcc=librosa.feature.mfcc(signal,n_mfcc=20,sr=sr)
# Out:
# C:\Users\braha\AppData\Local\Temp\ipykernel_109052\187242446.py:5: FutureWarning: Pass y=[0.00397786 0.00702565 0.00599182 ... 0.00799827 0.00873168 0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mfcc=librosa.feature.mfcc(signal,n_mfcc=20,sr=sr)

# %%
mfcc.shape
# Out:
# (20, 89)

# %%
plt.figure(figsize=(25,10))
librosa.display.specshow(mfcc,x_axis='time',sr=sr)
plt.colorbar(format="%+2f")
plt.show()

# %%
#calculate delata and delta2 MFFCS
delta_mfccs=librosa.feature.delta(mfcc)
delata2_mfccs=librosa.feature.delta(mfcc,order=2)

# %%
delta_mfccs.shape
# Out:
# (20, 89)

# %%
plt.figure(figsize=(25,10))
librosa.display.specshow(delta_mfccs,x_axis='time',sr=sr)
plt.colorbar(format="%+2f")
plt.title('derivative of mfccs')
plt.show()

# %%
plt.figure(figsize=(25,10))
librosa.display.specshow(delata2_mfccs,x_axis='time',sr=sr)
plt.colorbar(format="%+2f")
plt.show()

# %% [markdown]
# # Mel filter banks

# %%
filter_banks = librosa.filters.mel(n_fft=2048, sr=16000, n_mels=10)

# %%
filter_banks.shape
# Out:
# (10, 1025)

# %%
plt.figure(figsize=(25, 10))
librosa.display.specshow(filter_banks, 
                         sr=sr, 
                         x_axis="linear")
plt.colorbar(format="%+2.f")
plt.show()

# %% [markdown]
# # Extracting Mel Spectrogram

# %%
mel_spectrogram = librosa.feature.melspectrogram(signal, sr=16000, n_fft=2048, hop_length=512, n_mels=10)
# Out:
# C:\Users\braha\AppData\Local\Temp\ipykernel_109052\1855782389.py:1: FutureWarning: Pass y=[0.00397786 0.00702565 0.00599182 ... 0.00799827 0.00873168 0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel_spectrogram = librosa.feature.melspectrogram(signal, sr=16000, n_fft=2048, hop_length=512, n_mels=10)

# %%
log_mel_spectrogram = librosa.power_to_db(mel_spectrogram)

# %%
log_mel_spectrogram.shape
# Out:
# (10, 89)

# %%
plt.figure(figsize=(25, 10))
librosa.display.specshow(log_mel_spectrogram, 
                         x_axis="time",
                         y_axis="mel", 
                         sr=sr)
plt.colorbar(format="%+2.f")
plt.show()

# %% [markdown]
# # commentaires
# - time step 0.5 represent word please,
# - time step 1  represent call
# - time step 1.5  represent stella
