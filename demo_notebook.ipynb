# %%
import os 
import sys
import random
import librosa
import demo
import subprocess
import command

from IPython.display import Audio

# %%
# Extracting the current path
current_path = os.path.dirname(os.path.abspath('__file__'))
current_path
# Out:
# 'c:\\Users\\Brani\\OneDrive\\Bureau\\GitHub\\WaveNet\\WaveNet'

# %%
# Loading a sound file 
full_path_data = os.path.join(current_path, 'data', 'VCTK-Corpus')
full_path_data
# Out:
# 'c:\\Users\\Brani\\OneDrive\\Bureau\\GitHub\\WaveNet\\WaveNet\\data\\VCTK-Corpus'

# %%
# Extract all souds of dataset
paths_audio_sounds = []
for root, dirs, files in os.walk(full_path_data):
    for file in files:
        if file.endswith('.wav'):
            paths_audio_sounds.append(os.path.join(root, file))

# %%
# choose a random sound 
sound_path = random.choice(paths_audio_sounds)
sound_path
# Out:
# 'c:\\Users\\Brani\\OneDrive\\Bureau\\GitHub\\WaveNet\\WaveNet\\data\\VCTK-Corpus\\wav48\\p226\\p226_003.wav'

# %%
# display audio
sound, rs = librosa.load(sound_path, sr=None)
Audio(data=sound, rate=rs)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
os.system("demo.py --input_path=sound_path")
# Out:
# 1

# %%
# Generate a text sequence from a randomly selected sound 
# !python demo.py # --input_path=sound_path
# Out:
# I1222 19:01:18.182765 40044 utils.py:84] Load trained_models\best.json: sample_rate=16000, num_channel=20, num_vocabulary=28.
# W1222 19:01:18.406956 40044 warnings.py:109] c:\Users\Brani\anaconda3\envs\env_ML\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1694: UserWarning: `layer.apply` is deprecated and will be removed in a future version. Please use `layer.__call__` method instead.
#   warnings.warn('`layer.apply` is deprecated and '
#
# 2022-12-22 19:01:24.393161: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-22 19:01:26.681084: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1335 MB memory:  -> device: 0, name: NVIDIA GeForce MX250, pci bus id: 0000:01:00.0, compute capability: 6.1
# 2022-12-22 19:01:26.795215: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:354] MLIR V1 optimization pass is not enabled
# INFO:tensorflow:Restoring parameters from trained_models\best
# I1222 19:01:28.369409 40044 saver.py:1410] Restoring parameters from trained_models\best
# W1222 19:01:29.711831 40044 warnings.py:109] c:\Users\Brani\anaconda3\envs\env_ML\lib\site-packages\librosa\util\decorators.py:88: UserWarning: PySoundFile failed. Trying audioread instead.
#   return f(*args, **kwargs)
#
# Traceback (most recent call last):
#   File "c:\Users\Brani\anaconda3\envs\env_ML\lib\site-packages\librosa\core\audio.py", line 164, in load
#     y, sr_native = __soundfile_load(path, offset, duration, dtype)
#   File "c:\Users\Brani\anaconda3\envs\env_ML\lib\site-packages\librosa\core\audio.py", line 195, in __soundfile_load
#     context = sf.SoundFile(path)
#   File "c:\Users\Brani\anaconda3\envs\env_ML\lib\site-packages\soundfile.py", line 655, in __init__
#     self._file = self._open(file, mode_int, closefd)
#   File "c:\Users\Brani\anaconda3\envs\env_ML\lib\site-packages\soundfile.py", line 1213, in _open
#     raise LibsndfileError(err, prefix="Error opening {0!r}: ".format(self.name))
# soundfile.LibsndfileError: Error opening 'sound_path': System error.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\Brani\OneDrive\Bureau\GitHub\WaveNet\WaveNet\demo.py", line 39, in <module>
#     tf.compat.v1.app.run()
#   File "c:\Users\Brani\anaconda3\envs\env_ML\lib\site-packages\tensorflow\python\platform\app.py", line 36, in run
#     _run(main=main, argv=argv, flags_parser=_parse_flags_tolerate_undef)
#   File "c:\Users\Brani\anaconda3\envs\env_ML\lib\site-packages\absl\app.py", line 308, in run
#     _run_main(main, args)
#   File "c:\Users\Brani\anaconda3\envs\env_ML\lib\site-packages\absl\app.py", line 254, in _run_main
#     sys.exit(main(argv))
#   File "c:\Users\Brani\OneDrive\Bureau\GitHub\WaveNet\WaveNet\demo.py", line 32, in main
#     wave = utils.read_wave(FLAGS.input_path)
#   File "c:\Users\Brani\OneDrive\Bureau\GitHub\WaveNet\WaveNet\utils.py", line 91, in read_wave
#     wave, sr = librosa.load(filepath, mono=True, sr=Data.sample_rate)
#   File "c:\Users\Brani\anaconda3\envs\env_ML\lib\site-packages\librosa\util\decorators.py", line 88, in inner_f
#     return f(*args, **kwargs)
#   File "c:\Users\Brani\anaconda3\envs\env_ML\lib\site-packages\librosa\core\audio.py", line 170, in load
#     y, sr_native = __audioread_load(path, offset, duration, dtype)
#   File "c:\Users\Brani\anaconda3\envs\env_ML\lib\site-packages\librosa\core\audio.py", line 226, in __audioread_load
#     reader = audioread.audio_open(path)
#   File "c:\Users\Brani\anaconda3\envs\env_ML\lib\site-packages\audioread\__init__.py", line 127, in audio_open
#     return BackendClass(path)
#   File "c:\Users\Brani\anaconda3\envs\env_ML\lib\site-packages\audioread\rawread.py", line 59, in __init__
#     self._fh = open(filename, 'rb')
# FileNotFoundError: [Errno 2] No such file or directory: 'sound_path'

# %%
nb_speakers = 3

# %%
data = dict.fromkeys(['speaker ' + str(i+1) for i in range(nb_speakers)], {'sound':[], 'text':[]})
data
# Out:
# {'speaker 1': {'sound': [], 'text': []},
#  'speaker 2': {'sound': [], 'text': []},
#  'speaker 3': {'sound': [], 'text': []}}

# %%
for root, dirs, files in os.walk(full_path_data):
    print(root)
    print(dirs)
    print(files)
    
    sys.exit()
    # for f in files:
    #     ...
    #     ...
    # break
# Out:
# c:\Users\Brani\OneDrive\Bureau\GitHub\WaveNet\WaveNet\data\VCTK-Corpus
# ['txt', 'wav48']
# ['speaker-info.txt']
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# C:\Users\Brani\AppData\Roaming\Python\Python310\site-packages\IPython\core\interactiveshell.py:3405: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
texts_paths, waves_paths = [], []
for text_path, wave_path in zip( os.listdir(os.path.join(full_path_data, 'txt')),
                                 os.listdir(os.path.join(full_path_data, 'wav48'))):
    texts_paths.append(os.path.join(full_path_data, 'txt', text_path))
    waves_paths.append(os.path.join(full_path_data, 'wav48', text_path))

texts_paths, waves_paths
# Out:
# (['c:\\Users\\Brani\\OneDrive\\Bureau\\GitHub\\WaveNet\\WaveNet\\data\\VCTK-Corpus\\txt\\p225',
#   'c:\\Users\\Brani\\OneDrive\\Bureau\\GitHub\\WaveNet\\WaveNet\\data\\VCTK-Corpus\\txt\\p226',
#   'c:\\Users\\Brani\\OneDrive\\Bureau\\GitHub\\WaveNet\\WaveNet\\data\\VCTK-Corpus\\txt\\p227'],
#  ['c:\\Users\\Brani\\OneDrive\\Bureau\\GitHub\\WaveNet\\WaveNet\\data\\VCTK-Corpus\\wav48\\p225',
#   'c:\\Users\\Brani\\OneDrive\\Bureau\\GitHub\\WaveNet\\WaveNet\\data\\VCTK-Corpus\\wav48\\p226',
#   'c:\\Users\\Brani\\OneDrive\\Bureau\\GitHub\\WaveNet\\WaveNet\\data\\VCTK-Corpus\\wav48\\p227'])

# %%
piano_sound, sr = librosa.load(os.path.join(full_path_soud_file, file_name), sr=None)
piano_sound
