# %% [markdown]
# ## Demo Speech To Text

# %%
import os 
import sys
import random
import librosa

from IPython.display import Audio
# Out:
# c:\Users\louna\anaconda3\lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated
#   "class": algorithms.Blowfish,

# %%
# choose a random sound 
sound_path = "C:\\Users\\louna\\Documents\\Nouveau dossier\\data\\VCTK-Corpus\\wav48\\p225\\p225_002.wav"

# %%
# display audio
sound, rs = librosa.load(sound_path, sr=None)
Audio(data=sound, rate=rs)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Generate a text sequence from a randomly selected sound 
Text = !python demo.py --input_path "data\\VCTK-Corpus\\wav48\\p225\\p225_002.wav"

# %%
print("Genereted text : ", Text[-1])
# Out:
# Genereted text :  ask her to bring these things with her from the store
